# %% [markdown]
# ## Nesse capítulo vamos abordar uma introdução ao ao MLOps(Machine Learning Operations), os benefícios, as etapas de um projeto e os perfis de profissionais que normalmente trabalham nesse tipo de abordagem

# %% [markdown]
# # MLOps é um conjunto de boas práticas para desenvolver, fazer deploy e monitorar modelos de machine learning de forma contínua, confiável e eficiente.
# ## O foco é colocar modelos de ML em produção e o ciclo de vida inteiro de ponta a ponta
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Os benefícios de se utilizar as boas práticas de MLOps são:
# 1. Velocidade
# 2. Confiabilidade e Segurança
# 3. Colaboração melhorada
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Falando um pouco melhor sobre as etapas de de MLOps, existem três:
# 1. Planejamento
# 2. Desenvolvimento
# 3. Deploy
#
# ## Na fase de planejamento, o foco é conhecer o problema, como a solução desejada vai trazer valor para o negócio, quais são os requisitos da área de negócio.
#
# ![image.png](attachment:image.png)
#
# ## Na fase de desenvolvimento, o foco é desenvolver o modelo de ML, testar os modelos mais adequados para o problema, pré-processamento, ajustar hiperparâmetros e fim o modelo deve estar pronto para o deploy
#
# ![image-2.png](attachment:image-2.png)
#
# ## Na fase de deploy, o foco é colocar o modelo de ML em produção e monitorar as métricas
#
# ![image-3.png](attachment:image-3.png)
